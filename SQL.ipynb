# %% [markdown]
# <a href="https://colab.research.google.com/github/Kethellem/cursopython/blob/main/SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-45714629-89d9-4f75-88d1-75fe18ce4bb7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45714629-89d9-4f75-88d1-75fe18ce4bb7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_transacoes = pd.read_csv("TB_TRANSACOES_PROJETO_ECOMM.csv", delimiter=';')
df_clientes = pd.read_csv("TB_CLIENTES_PROJETO_ECOMM.csv", delimiter = ';')

# %%
conn = sqlite3.connect('projeto.db')
# Carregar o DataFrame no banco de dados SQLite - criando tb_transacoes e tb_clientes
df_transacoes.to_sql('tb_transacoes', conn , index=False, if_exists='replace')
df_clientes.to_sql('tb_clientes', conn, index=False , if_exists='replace')
# Out:
# 175

# %%
# Função para executar consultas SQL e retornar o resultado com um DataFrame
def run_query(query):
  return pd.read_sql_query(query, conn)

# %%
conn =sqlite3.connect('projeto.db')
query = """
SELECT
    a.id_client,
    b.First_name,
    b.Gender,
    b.state_name,
    a.Category,
    a.Price
FROM tb_transacoes AS a
INNER JOIN tb_clientes AS b
    ON a.id_client = b.Id_client
ORDER BY a.Price DESC
"""

result_df = run_query(query)
print(result_df)
# Out:
#      id_client First_name       Gender state_name    Category  Price
# 0          112    Ingemar  Genderqueer         TX     Jewelry  99,85
# 1           64      Lucio       Female         SD      Health  99,37
# 2          122      Inigo       Female         KS        Home  99,16
# 3           30     Moishe       Female         OH  Industrial  99,03
# 4           76       Raul         Male         TX       Shoes  98,09
# ..         ...        ...          ...        ...         ...    ...
# 291         58      Emlyn       Female         NV        Toys  10,73
# 292         24   Harcourt       Female         GA     Grocery  10,44
# 293        161   Dietrich         Male         NC  Industrial   1,86
# 294        165   Ricoriki         Male         AL    Outdoors   1,72
# 295        126     Anatol         Male         NJ        Kids   0,51
#
# [296 rows x 6 columns]

# %% [markdown]
# O **INNER JOIN** foi utilizado porque o objetivo da consulta é combinar informações das transações com os dados dos clientes, garantindo que somente registros que existam nas duas tabelas apareçam no resultado.

# %%
# Exportando dados para csv
result_df.to_csv('resultado_consulta.csv', index=False)
from google.colab import files
files.download("resultado_consulta.csv")
