# %% [markdown]
# <a href="https://colab.research.google.com/github/Kethellem/cursopython/blob/main/preprocessamentodadosteste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7c947acf-eccb-4740-8f6a-77663d030e7e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c947acf-eccb-4740-8f6a-77663d030e7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Importação de dados de acordo com o diretório
df = pd.read_csv('TELECON.csv', delimiter=';')
df.head(10)
# Out:
#    customerID  Genero  Idoso Casado Dependents  Tempo_como_Cliente  \
# 0  7590-VHVEG  Female      0    Yes         No                   1
# 1  5575-GNVDE    Male      0     No         No                  34
# 2  3668-QPYBK    Male      0     No         No                   2
# 3  7795-CFOCW    Male      0     No         No                  45
# 4  9237-HQITU     NaN      0     No         No                   2
# 5  9305-CDSKC     NaN      0     No         No                   8
# 6  1452-KIOVK     NaN      0     No        Yes                  22
# 7  6713-OKOMC     NaN      0     No         No                  10
# 8  7892-POOKP     NaN      0    Yes         No                  28
# 9  6388-TABGU     NaN      0     No        Yes                  62
#
#   PhoneService Servico_Internet Servico_Seguranca Suporte_Tecnico StreamingTV  \
# 0           No              DSL                No              No          No
# ...

# %%
#Com esse comando conseguimos verificar qual o tipo de dados de cada coluna.
df.dtypes
# Out:
# customerID             object
# Genero                 object
# Idoso                   int64
# Casado                 object
# Dependents             object
# Tempo_como_Cliente      int64
# PhoneService           object
# Servico_Internet       object
# Servico_Seguranca      object
# Suporte_Tecnico        object
# StreamingTV            object
# Tipo_Contrato          object
# PaymentMethod          object
# Pagamento_Mensal      float64
# Total_Pago            float64
# Churn                  object
# dtype: object

# %%
#Este codigo retornará True se houver algum valor nulo em qualquer lugar do DataFrame, e False caso contrário.
df.isnull().values.any()
# Out:
# np.True_

# %%
# Contar o numero de valores nulos em cada coluna
df.isnull().sum()
# Out:
# customerID               0
# Genero                  12
# Idoso                    0
# Casado                   0
# Dependents               0
# Tempo_como_Cliente       0
# PhoneService          1482
# Servico_Internet         0
# Servico_Seguranca        0
# Suporte_Tecnico          0
# StreamingTV              0
# Tipo_Contrato            0
# PaymentMethod            0
# Pagamento_Mensal       325
# Total_Pago               0
# Churn                    5
# dtype: int64

# %% [markdown]
# PORCENTAGME DE DADOS FALTANTES

# %%
# Para contar o número de valores nulos em cada coluna
(df.isnull().sum() / len(df)) * 100
# Out:
# customerID             0.00
# Genero                 0.48
# Idoso                  0.00
# Casado                 0.00
# Dependents             0.00
# Tempo_como_Cliente     0.00
# PhoneService          59.28
# Servico_Internet       0.00
# Servico_Seguranca      0.00
# Suporte_Tecnico        0.00
# StreamingTV            0.00
# Tipo_Contrato          0.00
# PaymentMethod          0.00
# Pagamento_Mensal      13.00
# Total_Pago             0.00
# Churn                  0.20
# dtype: float64

# %% [markdown]
# COLUNA GENERO

# %% [markdown]
# Nessa coluna temos apenas 0.48% dos dados faltantes pouco para uma base tão grande

# %%
df[df['Genero'].isnull()]
# Out:
#     customerID Genero  Idoso Casado Dependents  Tempo_como_Cliente  \
# 4   9237-HQITU    NaN      0     No         No                   2
# 5   9305-CDSKC    NaN      0     No         No                   8
# 6   1452-KIOVK    NaN      0     No        Yes                  22
# 7   6713-OKOMC    NaN      0     No         No                  10
# 8   7892-POOKP    NaN      0    Yes         No                  28
# 9   6388-TABGU    NaN      0     No        Yes                  62
# 10  9763-GRSKD    NaN      0    Yes        Yes                  13
# 11  7469-LKBCI    NaN      0     No         No                  16
# 12  8091-TTVAX    NaN      0    Yes         No                  58
# 13  0280-XJGEX    NaN      0     No         No                  49
# 14  5129-JLPIS    NaN      0     No         No                  25
# 15  3655-SNQYZ    NaN      0    Yes        Yes                  69
#
#    PhoneService Servico_Internet    Servico_Seguranca      Suporte_Tecnico  \
# ...

# %% [markdown]
# Excluindo valores faltantes da coluna Genero

# %%
# Excluindo
df.dropna(subset=['Genero'], inplace=True)
#InplaceTrue faz com que as alterações sejam feitas diretamente no DataFrame original

# %%
df['Genero'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# a exclusão de dados faltantes na coluna Genero nao gera impacto na nossa base de dados já que a informação principal que queremos e Churn

# %% [markdown]
# COLUNA CustomerID

# %%
#Removendo coluna customerID
df.drop(columns=['customerID'], inplace=True)

# %% [markdown]
# Excluindo coluna customerID pois não são dados relevantes dentro do nosso modelo

# %% [markdown]
# COLUNA PHONESERVICE

# %% [markdown]
# preenchendo os nulos da coluna phoneservice com a moda (valor mais frequente)

# %%
# Encontrar o valor mais frequente (moda)
moda_PhoneService = df['PhoneService'].mode()

# Preencher os nulos com a moda
df['PhoneService'].fillna(moda_PhoneService, inplace=True)
# Out:
# /tmp/ipython-input-12-2467891387.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PhoneService'].fillna(moda_PhoneService, inplace=True)

# %%
# Verificando se ainda resta dandos faltantes
(df.isnull().sum() / len(df)) * 100
# Out:
# Genero                 0.000000
# Idoso                  0.000000
# Casado                 0.000000
# Dependents             0.000000
# Tempo_como_Cliente     0.000000
# PhoneService          59.565916
# Servico_Internet       0.000000
# Servico_Seguranca      0.000000
# Suporte_Tecnico        0.000000
# StreamingTV            0.000000
# Tipo_Contrato          0.000000
# PaymentMethod          0.000000
# Pagamento_Mensal      12.580386
# Total_Pago             0.000000
# Churn                  0.000000
# dtype: float64

# %% [markdown]
# “Realizei o tratamento dos dados faltantes.
# Na coluna PhoneService, os valores nulos foram preenchidos com o valor mais frequente encontrado no dataset.

# %% [markdown]
# COLUNA PAGAMENTO_MENSAL

# %% [markdown]
# Fazendo o tratamento dos dados da coluna pagamento_mensal com Média e Mediana para preencher o execesso de registros

# %%
# Analisando Média
df['Pagamento_Mensal'].mean()
# Out:
# np.float64(65.60756321839081)

# %%
# Analisando Mediana
df['Pagamento_Mensal'].median()
# Out:
# 71.45

# %% [markdown]
# SUBISTITUINDO PELA MEDIANA

# %%
mediana_Pagamento_Mensal = df['Pagamento_Mensal'].median()
# Substituindo os valores faltantes na coluna de Pagamento Mensal
df['Pagamento_Mensal'].fillna(mediana_Pagamento_Mensal, inplace=True)
# Out:
# /tmp/ipython-input-16-4289848837.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Pagamento_Mensal'].fillna(mediana_Pagamento_Mensal, inplace=True)

# %%
df['Pagamento_Mensal'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Verificando colunas se ainda possui dados faltantes
(df.isnull().sum() / len(df)) * 100
# Out:
# Genero                 0.000000
# Idoso                  0.000000
# Casado                 0.000000
# Dependents             0.000000
# Tempo_como_Cliente     0.000000
# PhoneService          59.565916
# Servico_Internet       0.000000
# Servico_Seguranca      0.000000
# Suporte_Tecnico        0.000000
# StreamingTV            0.000000
# Tipo_Contrato          0.000000
# PaymentMethod          0.000000
# Pagamento_Mensal       0.000000
# Total_Pago             0.000000
# Churn                  0.000000
# dtype: float64

# %% [markdown]
# Para a coluna Pagamento_Mensal, utilizei a mediana como forma de preenchimento, considerando que essa estratégia reduz impactos de possíveis outliers.

# %% [markdown]
# CORRIGINDO DADOS INCONSISTENTES

# %%
df['Servico_Internet'].unique()
# Out:
# array(['DSL', 'No', 'Fiber optic', 'dsl'], dtype=object)

# %%
#Transformando todos os dados da coluna Servico_Internet em caixa alta
df['Servico_Internet'] = df['Servico_Internet'].str.upper()

# %%
#Utilizando a função replace
df['Servico_Internet'] = df['Servico_Internet'].replace('DSL', 'DLS')

# %%
#Visualizando alterações
df['Servico_Internet'].unique()
# Out:
# array(['DLS', 'NO', 'FIBER OPTIC'], dtype=object)

# %% [markdown]
# Os dados errados foram subistituido pela correção em letras maiusculas utilizando o comando upper

# %% [markdown]
# PADRONIZANDO COLUNAS TODAS EM PORTUGUÊS

# %%
#Utilizando a função rename
df.rename(columns={'Dependents': 'Dependentes'}, inplace=True)
df.rename(columns={'PhoneService': 'Servico_Telefonico'}, inplace=True)
df.rename(columns={'StreamingTV': 'Transmissao_TV'}, inplace=True)
df.rename(columns={'PaymentMethod': 'Forma_Pagamento'}, inplace=True)

# %%
df.head()
# Out:
#     Genero  Idoso Casado Dependentes  Tempo_como_Cliente Servico_Telefonico  \
# 0   Female      0    Yes          No                   1                 No
# 1     Male      0     No          No                  34                Yes
# 2     Male      0     No          No                   2                Yes
# 3     Male      0     No          No                  45                 No
# 16       F      0     No          No                  52                Yes
#
#    Servico_Internet    Servico_Seguranca      Suporte_Tecnico  \
# 0               DLS                   No                   No
# 1               DLS                  Yes                   No
# 2               DLS                  Yes                   No
# 3               DLS                  Yes                  Yes
# 16               NO  No internet service  No internet service
#
#          Transmissao_TV   Tipo_Contrato            Forma_Pagamento  \
# ...

# %% [markdown]
# 1 - SALVANDO E ABRINDO ARQUIVO E CSV

# %%
df.to_csv('TELECON_TRATADO.csv', index=False)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#Carregando a base de dados tratada
df = pd.read_csv('TELECON_TRATADO.csv', delimiter=',')
df.head(10)
# Out:
#    Genero  Idoso Casado Dependentes  Tempo_como_Cliente Servico_Telefonico  \
# 0  Female      0    Yes          No                   1                 No
# 1    Male      0     No          No                  34                Yes
# 2    Male      0     No          No                   2                Yes
# 3    Male      0     No          No                  45                 No
# 4       F      0     No          No                  52                Yes
# 5    Male      0     No         Yes                  71                Yes
# 6       F      0    Yes         Yes                  10                Yes
# 7       F      0     No          No                  21                Yes
# 8    Male      1     No          No                   1                 No
# 9    Male      0    Yes          No                  12                Yes
#
#   Servico_Internet    Servico_Seguranca      Suporte_Tecnico  \
# 0              DLS                   No                   No
# ...

# %% [markdown]
# 2 - ANÁLISE UNIVARIADA

# %% [markdown]
# **A) Utilize a função describe no seu dataframe, veja os insigths que consegue retirar.**
#
# **B) Já é possível identificar variáveis com possíveis outliers? Se sim. Quais ?**
#
# **C) Plot gráficos que considerar importante para completar sua análise univariada.(Lembrando que sua variavel preditora é o churn). Não se esqueça de trazer insights de cada gráfico plotado. Utilize pelo menos 4 váriaveis distintas.**
#
# **D) Verifique se os dados das variáveis Booleanas são balanceados ou não.**

# %%
# Utilizando a função discribe para dar um panorama das nossas variáveus QUANTITATIVAS
df.describe()
# Out:
#              Idoso  Tempo_como_Cliente  Pagamento_Mensal   Total_Pago
# count  2488.000000         2488.000000       2488.000000  2488.000000
# mean      0.161576           32.352090         66.342564  2290.087178
# std       0.368135           24.636885         28.051718  2264.585643
# min       0.000000            0.000000         18.400000    18.800000
# 25%       0.000000            8.000000         45.400000   402.337500
# 50%       0.000000           29.000000         71.450000  1402.900000
# 75%       0.000000           56.000000         87.712500  3867.162500
# max       1.000000           72.000000        118.650000  8564.750000

# %% [markdown]
# É possível identificar outliers observando o describe():
# Variáveis como Pagamento_Mensal (valores muito altos acima do esperado).
# Total_Pago (grande variação e valores extremos).

# %% [markdown]
# Plotando gráficos para análise univariada (mínimo 4 variáveis)

# %%
# 1. Distribuição da variável Churn
sns.countplot(x='Churn', data=df)
plt.title('Distribuição do Churn')
plt.show()

# %% [markdown]
# Insight:
# Existe um desequilíbrio: a maioria dos clientes não cancelou o serviço (Churn = 0). Esse desbalanceamento é importante na modelagem preditiva.

# %%
# 2 Boxplot de Pagamento_Mensal
sns.boxplot(x=df['Pagamento_Mensal'])
plt.title('Boxplot - Pagamento Mensal')
plt.show()

# %% [markdown]
# Insight:
# Clientes com pagamento mensal superior a R$100 podem representar planos especiais ou casos extremos. Possíveis outliers detectados

# %%
# 3. Histograma de Tempo_como_Cliente
sns.histplot(df['Tempo_como_Cliente'], bins=20, kde=True)
plt.title('Histograma - Tempo como Cliente')
plt.show()

# %% [markdown]
# Insight:
# Grande parte dos clientes tem menos de 30 meses de relacionamento com a empresa. Isso pode indicar baixa fidelização.

# %%
# Boxplot de Total_Pago
sns.boxplot(x=df['Total_Pago'])
plt.title('Boxplot - Total Pago')
plt.show()

# %% [markdown]
# Insight:
# Valores pagos acima de R$6000 são raros e destoam da média. Esses casos extremos podem afetar a análise e devem ser avaliados.

# %%
#  Verificação do balanceamento de variáveis booleanas
# Exemplo para 'Idoso'
sns.countplot(x='Idoso', data=df)
plt.title('Distribuição - Idoso')
plt.show()

# %% [markdown]
# 3 - IDENTIFICAR E TRATAR AS COLUNAS QUE CONTÉM OUTLIERS

# %%
import plotly.express as px

# %%
df_nao_zero = df[df['Pagamento_Mensal'] != 0]

fig = px.box(df_nao_zero, y='Pagamento_Mensal', title='Box Plot Pagamento_Mensal (Valores Diferente de Zero)', labels={'Pagamento_Mensal': 'Valores'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_nao_zero = df[df['Total_Pago'] != 0]

fig = px.box(df_nao_zero, y='Total_Pago', title='Box Plot Total_Pago (Valores Diferente de Zero)', labels={'Pagamento_Mensal': 'Valores'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 2. Função para detectar outliers usando IQR
def detectar_outliers_iqr(df, coluna):
    Q1 = df[coluna].quantile(0.25)
    Q3 = df[coluna].quantile(0.75)
    IQR = Q3 - Q1
    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR
    outliers = df[(df[coluna] < limite_inferior) | (df[coluna] > limite_superior)]
    return outliers

# Verificando número de outliers em cada coluna
for coluna in colunas_analise:
    outliers = detectar_outliers_iqr(df, coluna)
    print(f'{coluna}: {len(outliers)} outliers detectados')
# Out:
# Tempo_como_Cliente: 0 outliers detectados
# Pagamento_Mensal: 0 outliers detectados
# Total_Pago: 0 outliers detectados

# %% [markdown]
# Não foram identificados outliers nas variáveis ​​numéricas da minha base, pois os valores máximos e mínimos estão dentro do esperado e os boxplots não mostram pontos discrepantes. Isso sugere que o pré-processamento anterior foi eficiente nesse aspecto. Portanto, não realizei nenhuma alteração em relação a outliers.

# %% [markdown]
# **Conclusão sobre outliers:**
#
# Após aplicar o método de detecção de outliers baseado no IQR (Intervalo Interquartil), não foram encontrados valores considerados extremos nas variáveis numéricas analisadas (`Tempo_como_Cliente`, `Pagamento_Mensal`, `Total_Pago`).
# Além disso, os boxplots não apresentaram pontos fora dos limites superiores ou inferiores esperados.
# Isso indica que o pré-processamento anterior foi eficiente na limpeza e padronização dos dados, e nenhuma ação adicional foi necessária nesta etapa.

# %% [markdown]
# 4 - ANÁLISE BIVARIADA:

# %% [markdown]
# A) Quetione pelo menos 5 informações e traga as respostas utilizando visuais gráficos e insights
#
# B) Quais variáveis você acredita serem as mais importantes para esse projeto  relacionadas a variável Churn ?

# %%
# 1. Clientes idosos têm maior tendência de churn?
sns.countplot(x='Idoso', hue='Churn', data=df)
plt.title('Churn por Faixa Etária (Idoso)')
plt.xlabel('Idoso (0 = Não, 1 = Sim)')
plt.ylabel('Total de Clientes')
plt.show()

# %% [markdown]
# A maioria dos clientes que cancelam não são idosos.
# Isso pode indicar que clientes mais jovens têm maior rotatividade, talvez por serem mais exigentes ou mais propensos a testar concorrentes.

# %%
# 2.O tempo como cliente influencia na chance de churn?
sns.boxplot(x='Churn', y='Tempo_como_Cliente', data=df)
plt.title('Churn por Tempo como Cliente')
plt.xlabel('Churn')
plt.ylabel('Meses como Cliente')
plt.show()

# %% [markdown]
# Clientes com menos tempo de contrato tendem a cancelar mais.
# A retenção parece melhorar após aproximadamente 30 meses. Isso reforça a importância de ações de fidelização nos primeiros meses.

# %%
# 3.Clientes com pagamentos mensais mais altos cancelam mais?
sns.boxplot(x='Churn', y='Pagamento_Mensal', data=df)
plt.title('Churn por Pagamento Mensal')
plt.xlabel('Churn')
plt.ylabel('R$')
plt.show()

# %% [markdown]
# Clientes que pagam valores mais altos mensalmente têm maior tendência de churn.
# Isso pode indicar insatisfação com o custo-benefício ou sensibilidade ao preço.

# %%
# 4.O valor total pago tem relação com o churn?
sns.boxplot(x='Churn', y='Total_Pago', data=df)
plt.title('Churn por Total Pago')
plt.xlabel('Churn')
plt.ylabel('Valor Total Pago (R$)')
plt.show()

# %% [markdown]
# Clientes que já pagaram muito ao longo do tempo (valores altos) têm menor taxa de churn.
# Isso mostra que a empresa consegue manter clientes de longo prazo, o que é positivo.

# %%
# 5.A proporção de churn está balanceada ou desequilibrada?
sns.countplot(x='Churn', data=df)
plt.title('Distribuição de Churn na Base')
plt.xlabel('Churn (0 = Não cancelou, 1 = Cancelou)')
plt.ylabel('Quantidade')
plt.show()

# %% [markdown]
# A maioria dos clientes não cancelou o serviço (classe 0).
# Esse desequilíbrio de classes é importante na modelagem preditiva e requer atenção (técnicas como balanceamento de dados).
